# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Happiness Report Analysis Using Python

# %% [markdown]
# # Data collection

# %%
#data loading in pandas frame
data=pd.read_csv('world-happiness-report-2021.csv')

# %%
#check first five rows of the dataset
data.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
#check last five rows of the dataset
data.tail()
# Out:
#     Country name  Regional indicator  Ladder score  \
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 144                           0.120         3.748         3.276
# 145                           0.074         3.611         3.322
# 146                           0.068         3.548         3.282
# 147                           0.058         3.259         3.030
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 144                  7.926           0.787                   48.700
# 145                  9.782           0.784                   59.269
# ...

# %%
#check shape of the dataset
data.shape
# Out:
# (149, 20)

# %%
#check more infomation of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
#check mathamtic realtioship of the dataset
data.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %%
#check corr realtioship of the dataset
data.corr()
# Out:
#                                             Ladder score  \
# Ladder score                                    1.000000
# Standard error of ladder score                 -0.470787
# upperwhisker                                    0.999347
# lowerwhisker                                    0.999396
# Logged GDP per capita                           0.789760
# Social support                                  0.756888
# Healthy life expectancy                         0.768099
# Freedom to make life choices                    0.607753
# Generosity                                     -0.017799
# Perceptions of corruption                      -0.421140
# Ladder score in Dystopia                             NaN
# Explained by: Log GDP per capita                0.789745
# Explained by: Social support                    0.756869
# Explained by: Healthy life expectancy           0.768138
# Explained by: Freedom to make life choices      0.607793
# ...

# %%
#check missing value of the dataset
data.isnull().sum()
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %% [markdown]
# # Visualization Configurations

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size']=12
plt.rcParams['figure.figsize']=(8,6)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Let's see what columns are in the dataset

# %%
data.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
# We select only the relevant columns

cols=['Country name', 'Regional indicator', 'Ladder score','Logged GDP per capita', 'Social support', 
      'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']

# %%
df=data[cols]

# %% [markdown]
# ## Rename Columns for Interpretability

# %%
#re name same columns
df.rename({'Country name':'country','Regional indicator':'region',
          'Logged GDP per capita':'GDP_per_capita','Social support':'social_score',
          'Healthy life expectancy':'life_expectancy',
           'Freedom to make life choices':'freedom_choice','Generosity':'generosity',
          'Perceptions of corruption':'corruption_score',
          'Ladder score':'happiness_score'},axis=1,inplace=True)
# Out:
# /var/folders/mj/5s3mrwnj015gcbsgy8yghk400000gn/T/ipykernel_878/1051033645.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename({'Country name':'country','Regional indicator':'region',

# %%
#check dataset
df.sample(2)
# Out:
#         country                        region  happiness_score  \
# 134  Madagascar            Sub-Saharan Africa            4.208
# 46       Kuwait  Middle East and North Africa            6.106
#
#      GDP_per_capita  social_score  life_expectancy  freedom_choice  \
# 134           7.396         0.686           59.305           0.552
# 46           10.817         0.843           66.900           0.867
#
#      generosity  corruption_score
# 134      -0.005             0.803
# 46       -0.104             0.736

# %% [markdown]
# ## Checking for Nulls and duplicates

# %%
#check missing values
df.isnull().sum()
# Out:
# country             0
# region              0
# happiness_score     0
# GDP_per_capita      0
# social_score        0
# life_expectancy     0
# freedom_choice      0
# generosity          0
# corruption_score    0
# dtype: int64

# %%
#check duplicated value
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No nulls or duplicates present in our dataset

# %% [markdown]
# ## Statistical Summary of the Dataset

# %%
#check mathatic realtion
df.describe().T
# Out:
#                   count       mean       std     min     25%     50%     75%  \
# happiness_score   149.0   5.532839  1.073924   2.523   4.852   5.534   6.255
# GDP_per_capita    149.0   9.432208  1.158601   6.635   8.541   9.569  10.421
# social_score      149.0   0.814745  0.114889   0.463   0.750   0.832   0.905
# life_expectancy   149.0  64.992799  6.762043  48.478  59.802  66.603  69.600
# freedom_choice    149.0   0.791597  0.113332   0.382   0.718   0.804   0.877
# generosity        149.0  -0.015134  0.150657  -0.288  -0.126  -0.036   0.079
# corruption_score  149.0   0.727450  0.179226   0.082   0.667   0.781   0.845
#
#                      max
# happiness_score    7.842
# GDP_per_capita    11.647
# social_score       0.983
# life_expectancy   76.953
# freedom_choice     0.970
# generosity         0.542
# corruption_score   0.939

# %%
sns.histplot(data=df, x="happiness_score", color="skyblue", label="Sepal Length", kde=True)
# Out:
# <AxesSubplot:xlabel='happiness_score', ylabel='Count'>

# %%
sns.distplot(df['happiness_score'], color="red", label="Sepal Width", kde=True)
# Out:
# /Users/vikky/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='happiness_score', ylabel='Density'>

# %%
sns.histplot(data=df, x="GDP_per_capita", color="skyblue", label="Sepal Length", kde=True)
# Out:
# /Users/vikky/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='GDP_per_capita', ylabel='Count'>

# %%
sns.distplot(df['GDP_per_capita'], color="red", label="Sepal Width", kde=True)
# Out:
# /Users/vikky/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='GDP_per_capita', ylabel='Density'>

# %%
sns.histplot(data=df, x="social_score", color="skyblue", label="Sepal Length", kde=True)
# Out:
# <AxesSubplot:xlabel='social_score', ylabel='Count'>

# %%
sns.distplot(df['social_score'], color="red", label="Sepal Width", kde=True)
# Out:
# /Users/vikky/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='social_score', ylabel='Density'>

# %%
sns.histplot(data=df, x="life_expectancy", color="skyblue", label="Sepal Length", kde=True)
# Out:
# <AxesSubplot:xlabel='life_expectancy', ylabel='Count'>

# %%
sns.distplot(df['life_expectancy'], color="red", label="Sepal Width", kde=True)
# Out:
# /Users/vikky/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='life_expectancy', ylabel='Density'>

# %%
sns.histplot(data=df, x="freedom_choice", color="skyblue", label="Sepal Length", kde=True)
# Out:
# <AxesSubplot:xlabel='freedom_choice', ylabel='Count'>

# %%
sns.distplot(df['freedom_choice'], color="red", label="Sepal Width", kde=True)
# Out:
# /Users/vikky/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='freedom_choice', ylabel='Density'>

# %%
sns.histplot(data=df, x="generosity", color="skyblue", label="Sepal Length", kde=True)
# Out:
# <AxesSubplot:xlabel='generosity', ylabel='Count'>

# %%
sns.distplot(df['generosity'], color="red", label="Sepal Width", kde=True)
# Out:
# /Users/vikky/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='generosity', ylabel='Density'>

# %%
sns.histplot(data=df, x="corruption_score", color="skyblue", label="Sepal Length", kde=True)
# Out:
# <AxesSubplot:xlabel='corruption_score', ylabel='Count'>

# %%
sns.distplot(df['corruption_score'], color="red", label="Sepal Width", kde=True)
# Out:
# /Users/vikky/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='corruption_score', ylabel='Density'>

# %% [markdown]
# # Exploratory Data Analysis

# %%
#check unique value
df['region'].unique()
# Out:
# array(['West EU', 'North America/ ANZ', 'Middle East/ North Africa',
#        'Latin & Caribbean', 'Central & East EU', 'East Asia',
#        'Southeast Asia', 'Commonwealth', 'Sub-Saharan Africa',
#        'South Asia'], dtype=object)

# %%
#  Relation between happiness and GDP
plt.figure(figsize=(12,7))
sns.scatterplot(x='GDP_per_capita',y='happiness_score',hue='region',s=80,data=df)
plt.legend(loc='best',fontsize=10)
plt.title('Dependence of GDP per capita on Happiness',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Dependence of GDP per capita on Happiness')

# %%
#  Relation between happiness and life_expectancy
plt.figure(figsize=(12,7))
sns.scatterplot(x='life_expectancy',y='happiness_score',hue='region',s=80,data=df)
plt.legend(loc='best',fontsize=10)
plt.title('Dependence of Life Expectancy on Happiness',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Dependence of Life Expectancy on Happiness')

# %%
#  Relation between freedom of Choice and GDP
plt.figure(figsize=(12,7))
sns.scatterplot(x='freedom_choice',y='happiness_score',hue='region',s=80,data=df)
plt.legend(loc='best',fontsize=10)
plt.title('Dependence of freedom of Choice on Happiness',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Dependence of freedom of Choice on Happiness')

# %%
# Lets deep dive into GDP vs happiness for each region
happiness_region=df.groupby('region').mean()

# %%
happiness_region.head(2)
# Out:
#                                     happiness_score  GDP_per_capita  \
# region
# Central and Eastern Europe                 5.984765       10.109059
# Commonwealth of Independent States         5.467000        9.401833
#
#                                     social_score  life_expectancy  \
# region
# Central and Eastern Europe              0.887412        68.338412
# Commonwealth of Independent States      0.872500        65.009500
#
#                                     freedom_choice  generosity  \
# region
# Central and Eastern Europe                0.797059   -0.078941
# Commonwealth of Independent States        0.816917   -0.036000
#
#                                     corruption_score
# region
# Central and Eastern Europe                  0.850529
# Commonwealth of Independent States          0.725083

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='GDP_per_capita',y='happiness_score',hue='region',s=120,data=happiness_region)
plt.legend(loc='best',fontsize=10)
plt.title('Regionwise GDP and happiness',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Regionwise GDP and happiness')

# %%
# Lets rename the regions
def region(x):
    if x=='Western Europe':
        return 'West EU'
    elif x=='North America and ANZ':
        return 'North America/ ANZ'
    elif x=='Middle East and North Africa':
        return 'Middle East/ North Africa'
    elif x=='Latin America and Caribbean':
        return 'Latin & Caribbean'
    elif x=='Central and Eastern Europe':
        return 'Central & East EU'
    elif x=='Commonwealth of Independent States':
        return 'Commonwealth'
    else:
        return x

# %%
df['region'].value_counts()
# Out:
# Sub-Saharan Africa                    36
# Western Europe                        21
# Latin America and Caribbean           20
# Middle East and North Africa          17
# Central and Eastern Europe            17
# Commonwealth of Independent States    12
# Southeast Asia                         9
# South Asia                             7
# East Asia                              6
# North America and ANZ                  4
# Name: region, dtype: int64

# %%
df['region']=df['region'].apply(lambda x:region(x))
# Out:
# /var/folders/mj/5s3mrwnj015gcbsgy8yghk400000gn/T/ipykernel_878/3862801844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['region']=df['region'].apply(lambda x:region(x))

# %%
# Regionwise Nos of countries in the Happiness Report study
plt.figure(figsize=(15,4))
plt.bar(x=df['region'].value_counts().index,height=df['region'].value_counts().values)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Correlation

# %%
plt.figure(figsize=(6,5))
sns.heatmap(df.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
# Regionwise Happiness Score
plt.figure(figsize=(15,4))
sns.barplot(data=df,x='region',y='happiness_score')
plt.xticks(rotation=45)
plt.show()

# %%
# Regionwise Corruption Perception
plt.figure(figsize=(15,4))
sns.barplot(data=df,x='region',y='corruption_score')
plt.xticks(rotation=45)
plt.show()

# %%
# Regionwise GDP_per_capita
plt.figure(figsize=(15,4))
sns.barplot(data=df,x='region',y='GDP_per_capita')
plt.xticks(rotation=45)
plt.show()

# %%
# Regionwise Life Expectancy
plt.figure(figsize=(15,4))
sns.barplot(data=df,x='region',y='life_expectancy')
plt.xticks(rotation=45)
plt.show()

# %%
# Regionwise social_score
plt.figure(figsize=(15,4))
sns.barplot(data=df,x='region',y='social_score')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Top 5 vs Bottom 5 Comparisons

# %%
top_5=df.head(5)
bottom_5=df.tail(5)

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,sharey=True,figsize=(14,6))
plt.tight_layout(pad=2)

ax[0].set_title('Most happiest countries')
sns.barplot(x=top_5['country'],y=top_5['life_expectancy'],ax=ax[0])

ax[1].set_title('Least happiest countries')
sns.barplot(x=bottom_5['country'],y=bottom_5['life_expectancy'],ax=ax[1])
# Out:
# <AxesSubplot:title={'center':'Least happiest countries'}, xlabel='country', ylabel='life_expectancy'>

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,sharey=True,figsize=(14,6))
plt.tight_layout(pad=2)

ax[0].set_title('Most happiest countries')
sns.barplot(x=top_5['country'],y=top_5['GDP_per_capita'],ax=ax[0])

ax[1].set_title('Least happiest countries')
sns.barplot(x=bottom_5['country'],y=bottom_5['GDP_per_capita'],ax=ax[1])
# Out:
# <AxesSubplot:title={'center':'Least happiest countries'}, xlabel='country', ylabel='GDP_per_capita'>

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,sharey=True,figsize=(14,6))
plt.tight_layout(pad=2)

ax[0].set_title('Most happiest countries')
sns.barplot(x=top_5['country'],y=top_5['corruption_score'],ax=ax[0])

ax[1].set_title('Least happiest countries')
sns.barplot(x=bottom_5['country'],y=bottom_5['corruption_score'],ax=ax[1])
# Out:
# <AxesSubplot:title={'center':'Least happiest countries'}, xlabel='country', ylabel='corruption_score'>

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,sharey=True,figsize=(14,6))
plt.tight_layout(pad=2)

ax[0].set_title('Most happiest countries')
sns.barplot(x=top_5['country'],y=top_5['freedom_choice'],ax=ax[0])

ax[1].set_title('Least happiest countries')
sns.barplot(x=bottom_5['country'],y=bottom_5['freedom_choice'],ax=ax[1])
# Out:
# <AxesSubplot:title={'center':'Least happiest countries'}, xlabel='country', ylabel='freedom_choice'>

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,sharey=True,figsize=(14,6))
plt.tight_layout(pad=2)

ax[0].set_title('Most happiest countries')
sns.barplot(x=top_5[''],y=top_5['generosity'],ax=ax[0])

ax[1].set_title('Least happiest countries')
sns.barplot(x=bottom_5['country'],y=bottom_5['generosity'],ax=ax[1])
# Out:
# <AxesSubplot:title={'center':'Least happiest countries'}, xlabel='country', ylabel='generosity'>

# %%
plt.figure(figsize=(10,25))
plt.fill_between(data['Ladder score'], data['Country name'])
plt.show()

# %% [markdown]
# # Logged GDP per capita

# %%
x = np.array(data['Ladder score'])
for i in range(len(x)):
    fit = -0.0747281 *x*x*x + 1.05045076*x*x -3.16337971*x +7.10682006
bound_country = ['Kuwait','Guatemala','Jamaica','Costa Rica','Kosovo','Brazil','El Salvador','Uzbekistan','United Arab Emirates','Singapore','Ireland','Luxembourg']
plt.figure(figsize=(20,13))
sns.scatterplot(data= data, x='Ladder score',y='Logged GDP per capita',s=100)
plt.title('Life Satisfication vs GDP per Captia',fontsize=30,color = 'dimgray')
plt.axis('off')

plt.plot(x,fit,lw=8,alpha=0.3)
for i in range(len(data)):
    if data.loc[i,'Country name'] in bound_country:
        plt.text(s =data.loc[i,'Country name'], x=data.loc[i,'Ladder score']+0.01,y=data.loc[i,'Logged GDP per capita']+0.01, fontsize=10,color='lightgrey')
        plt.scatter(x=data.loc[i,'Ladder score'],y=data.loc[i,'Logged GDP per capita'],color ='lightgrey',s=100)
    else:
        plt.text(s =data.loc[i,'Country name'], x=data.loc[i,'Ladder score']+0.01,y=data.loc[i,'Logged GDP per capita']+0.01, fontsize=10)

plt.text(s='x: Life Satisfication',x=7.3,y=9.4,fontsize=20)
plt.text(s='y: GDP per Captia',x=7.3,y=9.3,fontsize=20)
        
plt.show()
